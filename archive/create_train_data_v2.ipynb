# %%
import pandas as pd

pd.set_option('display.max_colwidth', None)

question_solution_pairs = [
    #1
    (
        "How many transactions were placed in City B?",
        """def process_orders(df):\n    unique_orders = df[['order_id', 'customer_city']].drop_duplicates()\n    city_b_orders = unique_orders[unique_orders['customer_city'] == 'City B']\n    num_orders = len(city_b_orders)\n    return num_orders"""
    ),
    (
        "How many purchases were placed in City C?",
        """def process_orders(df):\n    unique_orders = df[['order_id', 'customer_city']].drop_duplicates()\n    city_c_orders = unique_orders[unique_orders['customer_city'] == 'City C']\n    num_orders = len(city_c_orders)\n    return num_orders"""
    ),
    (
        "How many orders were placed in City D?",
        """def process_orders(df):\n    unique_orders = df[['order_id', 'customer_city']].drop_duplicates()\n    city_d_orders = unique_orders[unique_orders['customer_city'] == 'City D']\n    num_orders = len(city_d_orders)\n    return num_orders"""
    ),
    (
        "How many purchases were placed in City A?",
        """def process_orders(df):\n    unique_orders = df[['order_id', 'customer_city']].drop_duplicates()\n    city_a_orders = unique_orders[unique_orders['customer_city'] == 'City A']\n    num_orders = len(city_a_orders)\n    return num_orders"""
    ),
    (
        "How many transactions were placed in City C?",
        """def process_orders(df):\n    unique_orders = df[['order_id', 'customer_city']].drop_duplicates()\n    city_c_orders = unique_orders[unique_orders['customer_city'] == 'City C']\n    num_orders = len(city_c_orders)\n    return num_orders"""
    ),
    (
        "How many transactions were placed in City D?",
        """def process_orders(df):\n    unique_orders = df[['order_id', 'customer_city']].drop_duplicates()\n    city_d_orders = unique_orders[unique_orders['customer_city'] == 'City D']\n    num_orders = len(city_d_orders)\n    return num_orders"""
    ),
    (
        "How many purchases were placed in City D?",
        """def process_orders(df):\n    unique_orders = df[['order_id', 'customer_city']].drop_duplicates()\n    city_d_orders = unique_orders[unique_orders['customer_city'] == 'City D']\n    num_orders = len(city_d_orders)\n    return num_orders"""
    ),
    (
        "How many sales were placed in City B?",
        """def process_orders(df):\n    unique_orders = df[['order_id', 'customer_city']].drop_duplicates()\n    city_b_orders = unique_orders[unique_orders['customer_city'] == 'City B']\n    num_orders = len(city_b_orders)\n    return num_orders"""
    ),
    (
        "How many sales were placed in City A?",
        """def process_orders(df):\n    unique_orders = df[['order_id', 'customer_city']].drop_duplicates()\n    city_a_orders = unique_orders[unique_orders['customer_city'] == 'City A']\n    num_orders = len(city_a_orders)\n    return num_orders"""
    ),
    (
        "How many orders were placed in City A?",
        """def process_orders(df):\n    unique_orders = df[['order_id', 'customer_city']].drop_duplicates()\n    city_a_orders = unique_orders[unique_orders['customer_city'] == 'City A']\n    num_orders = len(city_a_orders)\n    return num_orders"""
    ),
    #2
    (
        "What is the average price of products in the Electronics category?",
        """def calculate_average_price(df):\n    selected_columns = df[['product_category', 'product_id', 'price']]\n    unique_products = selected_columns.drop_duplicates()\n    electronics_products = unique_products[unique_products['product_category'] == 'Electronics']\n    average_price = electronics_products['price'].mean()\n    return average_price"""
    ),
    (
        "What is the average cost of items in the Electronics category?",
        """def calculate_average_price(df):\n    selected_columns = df[['product_category', 'product_id', 'price']]\n    unique_products = selected_columns.drop_duplicates()\n    electronics_products = unique_products[unique_products['product_category'] == 'Electronics']\n    average_price = electronics_products['price'].mean()\n    return average_price"""
    ),
    (
        "What is the average price of Electronics products?",
        """def calculate_average_price(df):\n    selected_columns = df[['product_category', 'product_id', 'price']]\n    unique_products = selected_columns.drop_duplicates()\n    electronics_products = unique_products[unique_products['product_category'] == 'Electronics']\n    average_price = electronics_products['price'].mean()\n    return average_price"""
    ),
    (
        "Calculate the mean price of items in Electronics.",
        """def calculate_average_price(df):\n    selected_columns = df[['product_category', 'product_id', 'price']]\n    unique_products = selected_columns.drop_duplicates()\n    electronics_products = unique_products[unique_products['product_category'] == 'Electronics']\n    average_price = electronics_products['price'].mean()\n    return average_price"""
    ),
    (
        "What is the average price of Electronics products?",
        """def calculate_average_price(df):\n    selected_columns = df[['product_category', 'product_id', 'price']]\n    unique_products = selected_columns.drop_duplicates()\n    electronics_products = unique_products[unique_products['product_category'] == 'Electronics']\n    average_price = electronics_products['price'].mean()\n    return average_price"""
    ),
    (
        "What is the average price for items in Electronics?",
        """def calculate_average_price(df):\n    selected_columns = df[['product_category', 'product_id', 'price']]\n    unique_products = selected_columns.drop_duplicates()\n    electronics_products = unique_products[unique_products['product_category'] == 'Electronics']\n    average_price = electronics_products['price'].mean()\n    return average_price"""
    ),
    (
        "What is the average price for products in Electronics?",
        """def calculate_average_price(df):\n    selected_columns = df[['product_category', 'product_id', 'price']]\n    unique_products = selected_columns.drop_duplicates()\n    electronics_products = unique_products[unique_products['product_category'] == 'Electronics']\n    average_price = electronics_products['price'].mean()\n    return average_price"""
    ),
    (
        "What is the average price of items in Electronics category?",
        """def calculate_average_price(df):\n    selected_columns = df[['product_category', 'product_id', 'price']]\n    unique_products = selected_columns.drop_duplicates()\n    electronics_products = unique_products[unique_products['product_category'] == 'Electronics']\n    average_price = electronics_products['price'].mean()\n    return average_price"""
    ),
    (
        "What is the mean price of Electronics items?",
        """def calculate_average_price(df):\n    selected_columns = df[['product_category', 'product_id', 'price']]\n    unique_products = selected_columns.drop_duplicates()\n    electronics_products = unique_products[unique_products['product_category'] == 'Electronics']\n    average_price = electronics_products['price'].mean()\n    return average_price"""
    ),
    (
        "Calculate the average price of Electronics products.",
        """def calculate_average_price(df):\n    selected_columns = df[['product_category', 'product_id', 'price']]\n    unique_products = selected_columns.drop_duplicates()\n    electronics_products = unique_products[unique_products['product_category'] == 'Electronics']\n    average_price = electronics_products['price'].mean()\n    return average_price"""
    ),
    (
        "What is the average price of products in the Clothing category?",
        """def calculate_average_price(df):\n    selected_columns = df[['product_category', 'product_id', 'price']]\n    unique_products = selected_columns.drop_duplicates()\n    clothing_products = unique_products[unique_products['product_category'] == 'Clothing']\n    average_price = clothing_products['price'].mean()\n    return average_price"""
    ),
    (
        "How much do products in the Books category cost on average?",
        """def calculate_average_price(df):\n    selected_columns = df[['product_category', 'product_id', 'price']]\n    unique_products = selected_columns.drop_duplicates()\n    books_products = unique_products[unique_products['product_category'] == 'Books']\n    average_price = books_products['price'].mean()\n    return average_price"""
    ),
    (
        "What is the average price of items in the Home & Kitchen category?",
        """def calculate_average_price(df):\n    selected_columns = df[['product_category', 'product_id', 'price']]\n    unique_products = selected_columns.drop_duplicates()\n    home_kitchen_products = unique_products[unique_products['product_category'] == 'Home & Kitchen']\n    average_price = home_kitchen_products['price'].mean()\n    return average_price"""
    ),
    (
        "What is the mean price of products in the Beauty category?",
        """def calculate_average_price(df):\n    selected_columns = df[['product_category', 'product_id', 'price']]\n    unique_products = selected_columns.drop_duplicates()\n    beauty_products = unique_products[unique_products['product_category'] == 'Beauty']\n    average_price = beauty_products['price'].mean()\n    return average_price"""
    ),
    (
        "Calculate the average price of items in the Sports & Outdoors category.",
        """def calculate_average_price(df):\n    selected_columns = df[['product_category', 'product_id', 'price']]\n    unique_products = selected_columns.drop_duplicates()\n    sports_outdoors_products = unique_products[unique_products['product_category'] == 'Sports & Outdoors']\n    average_price = sports_outdoors_products['price'].mean()\n    return average_price"""
    ),
    #3
    (
        "Show me the orders with a review score of 5.",
        """def filter_orders_by_review_score(df):\n    orders_with_review_5 = df[df['review_score'] == 5]\n    return orders_with_review_5"""
    ),
    (
        "Display orders having a review score of 5.",
        """def filter_orders_by_review_score(df):\n    orders_with_review_5 = df[df['review_score'] == 5]\n    return orders_with_review_5"""
    ),
    (
        "List orders where the review score is 5.",
        """def filter_orders_by_review_score(df):\n    orders_with_review_5 = df[df['review_score'] == 5]\n    return orders_with_review_5"""
    ),
    (
        "Find all orders with a review score of 5.",
        """def filter_orders_by_review_score(df):\n    orders_with_review_5 = df[df['review_score'] == 5]\n    return orders_with_review_5"""
    ),
    (
        "Retrieve orders that received a review score of 5.",
        """def filter_orders_by_review_score(df):\n    orders_with_review_5 = df[df['review_score'] == 5]\n    return orders_with_review_5"""
    ),
    (
        "Show me the orders where customers rated with 5 stars.",
        """def filter_orders_by_review_score(df):\n    orders_with_review_5 = df[df['review_score'] == 5]\n    return orders_with_review_5"""
    ),
    (
        "Display orders that got a 5-star review.",
        """def filter_orders_by_review_score(df):\n    orders_with_review_5 = df[df['review_score'] == 5]\n    return orders_with_review_5"""
    ),
    (
        "List all orders rated with 5 stars.",
        """def filter_orders_by_review_score(df):\n    orders_with_review_5 = df[df['review_score'] == 5]\n    return orders_with_review_5"""
    ),
    (
        "Find orders with a review score of 5.",
        """def filter_orders_by_review_score(df):\n    orders_with_review_5 = df[df['review_score'] == 5]\n    return orders_with_review_5"""
    ),
    (
        "Retrieve orders having a perfect review score of 5.",
        """def filter_orders_by_review_score(df):\n    orders_with_review_5 = df[df['review_score'] == 5]\n    return orders_with_review_5"""
    ),
    (
        "Show me the orders with a review score of 4.5.",
        """def filter_orders_by_review_score(df):\n    orders_with_review_45 = df[df['review_score'] == 4.5]\n    return orders_with_review_45"""
    ),
    (
        "Display orders having a review score of 3.7.",
        """def filter_orders_by_review_score(df):\n    orders_with_review_37 = df[df['review_score'] == 3.7]\n    return orders_with_review_37"""
    ),
    (
        "List orders where the review score is 4.2.",
        """def filter_orders_by_review_score(df):\n    orders_with_review_42 = df[df['review_score'] == 4.2]\n    return orders_with_review_42"""
    ),
    (
        "Find all orders with a review score of 2.9.",
        """def filter_orders_by_review_score(df):\n    orders_with_review_29 = df[df['review_score'] == 2.9]\n    return orders_with_review_29"""
    ),
    (
        "Retrieve orders that received a review score of 4.8.",
        """def filter_orders_by_review_score(df):\n    orders_with_review_48 = df[df['review_score'] == 4.8]\n    return orders_with_review_48"""
    ),
    #4
    (
        "What is the total quantity of Toys sold?",
        """def calculate_total_toys_sold(df):\n    toys_sold = df[df['product_category'] == 'Toys']['quantity'].sum()\n    return toys_sold"""
    ),
    (
        "How many Toys were sold in total?",
        """def calculate_total_toys_sold(df):\n    toys_sold = df[df['product_category'] == 'Toys']['quantity'].sum()\n    return toys_sold"""
    ),
    (
        "What is the sum of quantity for Toys?",
        """def calculate_total_toys_sold(df):\n    toys_sold = df[df['product_category'] == 'Toys']['quantity'].sum()\n    return toys_sold"""
    ),
    (
        "Calculate the total quantity of Toys sold.",
        """def calculate_total_toys_sold(df):\n    toys_sold = df[df['product_category'] == 'Toys']['quantity'].sum()\n    return toys_sold"""
    ),
    (
        "How many units of Toys were sold?",
        """def calculate_total_toys_sold(df):\n    toys_sold = df[df['product_category'] == 'Toys']['quantity'].sum()\n    return toys_sold"""
    ),
    (
        "What is the total quantity of Toy items sold?",
        """def calculate_total_toys_sold(df):\n    toys_sold = df[df['product_category'] == 'Toys']['quantity'].sum()\n    return toys_sold"""
    ),
    (
        "Find the total quantity of sold Toys.",
        """def calculate_total_toys_sold(df):\n    toys_sold = df[df['product_category'] == 'Toys']['quantity'].sum()\n    return toys_sold"""
    ),
    (
        "What is the total quantity of Toys that were sold?",
        """def calculate_total_toys_sold(df):\n    toys_sold = df[df['product_category'] == 'Toys']['quantity'].sum()\n    return toys_sold"""
    ),
    (
        "Calculate the sum of quantity for Toys.",
        """def calculate_total_toys_sold(df):\n    toys_sold = df[df['product_category'] == 'Toys']['quantity'].sum()\n    return toys_sold"""
    ),
    (
        "How many Toys have been sold?",
        """def calculate_total_toys_sold(df):\n    toys_sold = df[df['product_category'] == 'Toys']['quantity'].sum()\n    return toys_sold"""
    ),
    (
        "What is the total quantity of Electronics sold?",
        """def calculate_total_electronics_sold(df):\n    electronics_sold = df[df['product_category'] == 'Electronics']['quantity'].sum()\n    return electronics_sold"""
    ),
    (
        "How many Electronics were sold in total?",
        """def calculate_total_electronics_sold(df):\n    electronics_sold = df[df['product_category'] == 'Electronics']['quantity'].sum()\n    return electronics_sold"""
    ),
    (
        "What is the sum of quantity for Electronics?",
        """def calculate_total_electronics_sold(df):\n    electronics_sold = df[df['product_category'] == 'Electronics']['quantity'].sum()\n    return electronics_sold"""
    ),
    (
        "Calculate the total quantity of Electronics sold.",
        """def calculate_total_electronics_sold(df):\n    electronics_sold = df[df['product_category'] == 'Electronics']['quantity'].sum()\n    return electronics_sold"""
    ),
    (
        "How many units of Electronics were sold?",
        """def calculate_total_electronics_sold(df):\n    electronics_sold = df[df['product_category'] == 'Electronics']['quantity'].sum()\n    return electronics_sold"""
    ),
    (
        "What is the total quantity of Electronics items sold?",
        """def calculate_total_electronics_sold(df):\n    electronics_sold = df[df['product_category'] == 'Electronics']['quantity'].sum()\n    return electronics_sold"""
    ),
    (
        "Find the total quantity of sold Electronics.",
        """def calculate_total_electronics_sold(df):\n    electronics_sold = df[df['product_category'] == 'Electronics']['quantity'].sum()\n    return electronics_sold"""
    ),
    (
        "What is the total quantity of Electronics that were sold?",
        """def calculate_total_electronics_sold(df):\n    electronics_sold = df[df['product_category'] == 'Electronics']['quantity'].sum()\n    return electronics_sold"""
    ),
    (
        "Calculate the sum of quantity for Electronics.",
        """def calculate_total_electronics_sold(df):\n    electronics_sold = df[df['product_category'] == 'Electronics']['quantity'].sum()\n    return electronics_sold"""
    ),
    (
        "How many Electronics have been sold?",
        """def calculate_total_electronics_sold(df):\n    electronics_sold = df[df['product_category'] == 'Electronics']['quantity'].sum()\n    return electronics_sold"""
    ),
    (
        "What is the total quantity of Groceries sold?",
        """def calculate_total_groceries_sold(df):\n    groceries_sold = df[df['product_category'] == 'Groceries']['quantity'].sum()\n    return groceries_sold"""
    ),
    (
        "How many Groceries were sold in total?",
        """def calculate_total_groceries_sold(df):\n    groceries_sold = df[df['product_category'] == 'Groceries']['quantity'].sum()\n    return groceries_sold"""
    ),
    (
        "What is the sum of quantity for Groceries?",
        """def calculate_total_groceries_sold(df):\n    groceries_sold = df[df['product_category'] == 'Groceries']['quantity'].sum()\n    return groceries_sold"""
    ),
    (
        "Calculate the total quantity of Groceries sold.",
        """def calculate_total_groceries_sold(df):\n    groceries_sold = df[df['product_category'] == 'Groceries']['quantity'].sum()\n    return groceries_sold"""
    ),
    (
        "How many units of Housewares were sold?",
        """def calculate_total_housewares_sold(df):\n    housewares_sold = df[df['product_category'] == 'Housewares']['quantity'].sum()\n    return housewares_sold"""
    ),
    (
        "What is the total quantity of Groceries items sold?",
        """def calculate_total_groceries_sold(df):\n    groceries_sold = df[df['product_category'] == 'Groceries']['quantity'].sum()\n    return groceries_sold"""
    ),
    (
        "Find the total quantity of sold Groceries.",
        """def calculate_total_groceries_sold(df):\n    groceries_sold = df[df['product_category'] == 'Groceries']['quantity'].sum()\n    return groceries_sold"""
    ),
    (
        "What is the total quantity of Groceries that were sold?",
        """def calculate_total_groceries_sold(df):\n    groceries_sold = df[df['product_category'] == 'Groceries']['quantity'].sum()\n    return groceries_sold"""
    ),
    (
        "Calculate the sum of quantity for Groceries.",
        """def calculate_total_groceries_sold(df):\n    groceries_sold = df[df['product_category'] == 'Groceries']['quantity'].sum()\n    return groceries_sold"""
    ),
    (
        "How many Groceries have been sold?",
        """def calculate_total_groceries_sold(df):\n    groceries_sold = df[df['product_category'] == 'Groceries']['quantity'].sum()\n    return groceries_sold"""
    ),
    #5
    (
        "List all orders made by user ID 3.",
        """def filter_orders_by_user_id(df):\n    orders_by_user_3 = df[df['user_id'] == '3']\n    return orders_by_user_3"""
    ),
    (
        "Show orders placed by user ID 3.",
        """def filter_orders_by_user_id(df):\n    orders_by_user_3 = df[df['user_id'] == '3']\n    return orders_by_user_3"""
    ),
    (
        "Display orders where user ID is 3.",
        """def filter_orders_by_user_id(df):\n    orders_by_user_3 = df[df['user_id'] == '3']\n    return orders_by_user_3"""
    ),
    (
        "Retrieve all orders for user ID 3.",
        """def filter_orders_by_user_id(df):\n    orders_by_user_3 = df[df['user_id'] == '3']\n    return orders_by_user_3"""
    ),
    (
        "Find orders placed by user ID 3.",
        """def filter_orders_by_user_id(df):\n    orders_by_user_3 = df[df['user_id'] == '3']\n    return orders_by_user_3"""
    ),
    (
        "List orders where user ID is 3.",
        """def filter_orders_by_user_id(df):\n    orders_by_user_3 = df[df['user_id'] == '3']\n    return orders_by_user_3"""
    ),
    (
        "Show all orders of user ID 3.",
        """def filter_orders_by_user_id(df):\n    orders_by_user_3 = df[df['user_id'] == '3']\n    return orders_by_user_3"""
    ),
    (
        "Display orders made by user ID 3.",
        """def filter_orders_by_user_id(df):\n    orders_by_user_3 = df[df['user_id'] == '3']\n    return orders_by_user_3"""
    ),
    (
        "Retrieve orders for user ID 3.",
        """def filter_orders_by_user_id(df):\n    orders_by_user_3 = df[df['user_id'] == '3']\n    return orders_by_user_3"""
    ),
    (
        "Find all orders placed by user ID 3.",
        """def filter_orders_by_user_id(df):\n    orders_by_user_3 = df[df['user_id'] == '3']\n    return orders_by_user_3"""
    ),
    (
        "List all orders made by user ID XYZ.",
        """def filter_orders_by_user_id(df):\n    orders_by_user_xyz = df[df['user_id'] == 'XYZ']\n    return orders_by_user_xyz"""
    ),
    (
        "Show orders placed by user ID GHK.",
        """def filter_orders_by_user_id(df):\n    orders_by_user_ghk = df[df['user_id'] == 'GHK']\n    return orders_by_user_ghk"""
    ),
    (
        "Display orders where user ID is PQR.",
        """def filter_orders_by_user_id(df):\n    orders_by_user_pqr = df[df['user_id'] == 'PQR']\n    return orders_by_user_pqr"""
    ),
    (
        "Retrieve all orders for user ID LMN.",
        """def filter_orders_by_user_id(df):\n    orders_by_user_lmn = df[df['user_id'] == 'LMN']\n    return orders_by_user_lmn"""
    ),
    (
        "Find orders placed by user ID ABC.",
        """def filter_orders_by_user_id(df):\n    orders_by_user_abc = df[df['user_id'] == 'ABC']\n    return orders_by_user_abc"""
    ),
    #6
    (
        "What is the total amount on orders made by user ID 2?",
        """def calculate_total_sales_amount_for_user_2(df):\n    user_2_orders = df[df['user_id'] == '2']\n    user_2_orders['sales_amount'] = user_2_orders['quantity'] * user_2_orders['price']\n    total_sales_amount_user_2 = user_2_orders['sales_amount'].sum()\n    return total_sales_amount_user_2"""
    ),
    (
        "Calculate the total amount spent by user ID 2.",
        """def calculate_total_sales_amount_for_user_2(df):\n    user_2_orders = df[df['user_id'] == '2']\n    user_2_orders['sales_amount'] = user_2_orders['quantity'] * user_2_orders['price']\n    total_sales_amount_user_2 = user_2_orders['sales_amount'].sum()\n    return total_sales_amount_user_2"""
    ),
    (
        "How much did user ID 2 spend in total?",
        """def calculate_total_sales_amount_for_user_2(df):\n    user_2_orders = df[df['user_id'] == '2']\n    user_2_orders['sales_amount'] = user_2_orders['quantity'] * user_2_orders['price']\n    total_sales_amount_user_2 = user_2_orders['sales_amount'].sum()\n    return total_sales_amount_user_2"""
    ),
    (
        "What is the sum of sales amount for user ID 2?",
        """def calculate_total_sales_amount_for_user_2(df):\n    user_2_orders = df[df['user_id'] == '2']\n    user_2_orders['sales_amount'] = user_2_orders['quantity'] * user_2_orders['price']\n    total_sales_amount_user_2 = user_2_orders['sales_amount'].sum()\n    return total_sales_amount_user_2"""
    ),
    (
        "Find the total spending of user ID 2.",
        """def calculate_total_sales_amount_for_user_2(df):\n    user_2_orders = df[df['user_id'] == '2']\n    user_2_orders['sales_amount'] = user_2_orders['quantity'] * user_2_orders['price']\n    total_sales_amount_user_2 = user_2_orders['sales_amount'].sum()\n    return total_sales_amount_user_2"""
    ),
    (
        "Show the total amount spent by user ID 2.",
        """def calculate_total_sales_amount_for_user_2(df):\n    user_2_orders = df[df['user_id'] == '2']\n    user_2_orders['sales_amount'] = user_2_orders['quantity'] * user_2_orders['price']\n    total_sales_amount_user_2 = user_2_orders['sales_amount'].sum()\n    return total_sales_amount_user_2"""
    ),
    (
        "List total sales amount for user ID 2.",
        """def calculate_total_sales_amount_for_user_2(df):\n    user_2_orders = df[df['user_id'] == '2']\n    user_2_orders['sales_amount'] = user_2_orders['quantity'] * user_2_orders['price']\n    total_sales_amount_user_2 = user_2_orders['sales_amount'].sum()\n    return total_sales_amount_user_2"""
    ),
    (
        "Retrieve total spending of user ID 2.",
        """def calculate_total_sales_amount_for_user_2(df):\n    user_2_orders = df[df['user_id'] == '2']\n    user_2_orders['sales_amount'] = user_2_orders['quantity'] * user_2_orders['price']\n    total_sales_amount_user_2 = user_2_orders['sales_amount'].sum()\n    return total_sales_amount_user_2"""
    ),
    (
        "Calculate the total amount for user ID 2.",
        """def calculate_total_sales_amount_for_user_2(df):\n    user_2_orders = df[df['user_id'] == '2']\n    user_2_orders['sales_amount'] = user_2_orders['quantity'] * user_2_orders['price']\n    total_sales_amount_user_2 = user_2_orders['sales_amount'].sum()\n    return total_sales_amount_user_2"""
    ),
    (
        "How much did user ID 2 spend?",
        """def calculate_total_sales_amount_for_user_2(df):\n    user_2_orders = df[df['user_id'] == '2']\n    user_2_orders['sales_amount'] = user_2_orders['quantity'] * user_2_orders['price']\n    total_sales_amount_user_2 = user_2_orders['sales_amount'].sum()\n    return total_sales_amount_user_2"""
    ),
    (
        "What is the total amount on orders made by user ID XYZ?",
        """def calculate_total_sales_amount_for_user_xyz(df):\n    user_xyz_orders = df[df['user_id'] == 'XYZ']\n    user_xyz_orders['sales_amount'] = user_xyz_orders['quantity'] * user_xyz_orders['price']\n    total_sales_amount_user_xyz = user_xyz_orders['sales_amount'].sum()\n    return total_sales_amount_user_xyz"""
    ),
    (
        "Calculate the total amount spent by user ID GHK.",
        """def calculate_total_sales_amount_for_user_ghk(df):\n    user_ghk_orders = df[df['user_id'] == 'GHK']\n    user_ghk_orders['sales_amount'] = user_ghk_orders['quantity'] * user_ghk_orders['price']\n    total_sales_amount_user_ghk = user_ghk_orders['sales_amount'].sum()\n    return total_sales_amount_user_ghk"""
    ),
    (
        "How much did user ID PQR spend in total?",
        """def calculate_total_sales_amount_for_user_pqr(df):\n    user_pqr_orders = df[df['user_id'] == 'PQR']\n    user_pqr_orders['sales_amount'] = user_pqr_orders['quantity'] * user_pqr_orders['price']\n    total_sales_amount_user_pqr = user_pqr_orders['sales_amount'].sum()\n    return total_sales_amount_user_pqr"""
    ),
    (
        "What is the sum of sales amount for user ID LMN?",
        """def calculate_total_sales_amount_for_user_lmn(df):\n    user_lmn_orders = df[df['user_id'] == 'LMN']\n    user_lmn_orders['sales_amount'] = user_lmn_orders['quantity'] * user_lmn_orders['price']\n    total_sales_amount_user_lmn = user_lmn_orders['sales_amount'].sum()\n    return total_sales_amount_user_lmn"""
    ),
    (
        "Find the total spending of user ID ABC.",
        """def calculate_total_sales_amount_for_user_abc(df):\n    user_abc_orders = df[df['user_id'] == 'ABC']\n    user_abc_orders['sales_amount'] = user_abc_orders['quantity'] * user_abc_orders['price']\n    total_sales_amount_user_abc = user_abc_orders['sales_amount'].sum()\n    return total_sales_amount_user_abc"""
    ),
    #7
    (
        "How many unique product categories are there?",
        """def count_unique_product_categories(df):\n    unique_categories = df['product_category'].nunique()\n    return unique_categories"""
    ),
    (
        "Count the number of distinct product categories.",
        """def count_unique_product_categories(df):\n    unique_categories = df['product_category'].nunique()\n    return unique_categories"""
    ),
    (
        "What is the count of different product categories?",
        """def count_unique_product_categories(df):\n    unique_categories = df['product_category'].nunique()\n    return unique_categories"""
    ),
    (
        "Determine the number of unique product categories.",
        """def count_unique_product_categories(df):\n    unique_categories = df['product_category'].nunique()\n    return unique_categories"""
    ),
    (
        "count of unique product categories.",
        """def count_unique_product_categories(df):\n    unique_categories = df['product_category'].nunique()\n    return unique_categories"""
    ),
    (
        "How many distinct product categories are there?",
        """def count_unique_product_categories(df):\n    unique_categories = df['product_category'].nunique()\n    return unique_categories"""
    ),
    (
        "Find the total number of unique product categories.",
        """def count_unique_product_categories(df):\n    unique_categories = df['product_category'].nunique()\n    return unique_categories"""
    ),
    (
        "What is the total count of unique product categories?",
        """def count_unique_product_categories(df):\n    unique_categories = df['product_category'].nunique()\n    return unique_categories"""
    ),
    (
        "Calculate the number of unique product categories.",
        """def count_unique_product_categories(df):\n    unique_categories = df['product_category'].nunique()\n    return unique_categories"""
    ),
    (
        "Provide the count of unique product categories.",
        """def count_unique_product_categories(df):\n    unique_categories = df['product_category'].nunique()\n    return unique_categories"""
    ),
    #8
    (
        "List top 3 orders with the highest review scores.",
        """def get_top_3_orders_highest_review_scores(df):\n    top_3_orders = df[['order_id', 'review_score']].drop_duplicates()\n    top_3_orders = top_3_orders.sort_values(by='review_score', ascending=False)\n    top_3_orders = top_3_orders.head(3)\n    return top_3_orders"""
    ),
    (
        "Display the top 3 orders with the highest review scores.",
        """def get_top_3_orders_highest_review_scores(df):\n    top_3_orders = df[['order_id', 'review_score']].drop_duplicates()\n    top_3_orders = top_3_orders.sort_values(by='review_score', ascending=False)\n    top_3_orders = top_3_orders.head(3)\n    return top_3_orders"""
    ),
    (
        "Show top 3 orders based on the highest review scores.",
        """def get_top_3_orders_highest_review_scores(df):\n    top_3_orders = df[['order_id', 'review_score']].drop_duplicates()\n    top_3_orders = top_3_orders.sort_values(by='review_score', ascending=False)\n    top_3_orders = top_3_orders.head(3)\n    return top_3_orders"""
    ),
    (
        "Find the top 3 orders with the highest review scores.",
        """def get_top_3_orders_highest_review_scores(df):\n    top_3_orders = df[['order_id', 'review_score']].drop_duplicates()\n    top_3_orders = top_3_orders.sort_values(by='review_score', ascending=False)\n    top_3_orders = top_3_orders.head(3)\n    return top_3_orders"""
    ),
    (
        "Provide top 3 orders based on the highest review scores.",
        """def get_top_3_orders_highest_review_scores(df):\n    top_3_orders = df[['order_id', 'review_score']].drop_duplicates()\n    top_3_orders = top_3_orders.sort_values(by='review_score', ascending=False)\n    top_3_orders = top_3_orders.head(3)\n    return top_3_orders"""
    ),
    (
        "Get top 3 orders with the highest review scores.",
        """def get_top_3_orders_highest_review_scores(df):\n    top_3_orders = df[['order_id', 'review_score']].drop_duplicates()\n    top_3_orders = top_3_orders.sort_values(by='review_score', ascending=False)\n    top_3_orders = top_3_orders.head(3)\n    return top_3_orders"""
    ),
    (
        "List the top 3 orders having the highest review scores.",
        """def get_top_3_orders_highest_review_scores(df):\n    top_3_orders = df[['order_id', 'review_score']].drop_duplicates()\n    top_3_orders = top_3_orders.sort_values(by='review_score', ascending=False)\n    top_3_orders = top_3_orders.head(3)\n    return top_3_orders"""
    ),
    (
        "Find top 3 orders ranked by the highest review scores.",
        """def get_top_3_orders_highest_review_scores(df):\n    top_3_orders = df[['order_id', 'review_score']].drop_duplicates()\n    top_3_orders = top_3_orders.sort_values(by='review_score', ascending=False)\n    top_3_orders = top_3_orders.head(3)\n    return top_3_orders"""
    ),
    (
        "Show the top 3 orders with the highest review scores.",
        """def get_top_3_orders_highest_review_scores(df):\n    top_3_orders = df[['order_id', 'review_score']].drop_duplicates()\n    top_3_orders = top_3_orders.sort_values(by='review_score', ascending=False)\n    top_3_orders = top_3_orders.head(3)\n    return top_3_orders"""
    ),
    (
        "Retrieve top 3 orders based on the highest review scores.",
        """def get_top_3_orders_highest_review_scores(df):\n    top_3_orders = df[['order_id', 'review_score']].drop_duplicates()\n    top_3_orders = top_3_orders.sort_values(by='review_score', ascending=False)\n    top_3_orders = top_3_orders.head(3)\n    return top_3_orders"""
    ),
    (
        "List top 5 orders with the highest review scores.",
        """def list_top_orders_highest_review_scores(df):\n    top_orders = df[['order_id', 'review_score']].drop_duplicates()\n    top_orders = top_orders.sort_values(by='review_score', ascending=False)\n    top_5_orders = top_orders.head(5)\n    return top_5_orders"""
    ),
    (
        "Show the top 10 orders with the highest review scores.",
        """def list_top_orders_highest_review_scores(df):\n    top_orders = df[['order_id', 'review_score']].drop_duplicates()\n    top_orders = top_orders.sort_values(by='review_score', ascending=False)\n    top_10_orders = top_orders.head(10)\n    return top_10_orders"""
    ),
    (
        "Display top 7 orders with the highest review scores.",
        """def list_top_orders_highest_review_scores(df):\n    top_orders = df[['order_id', 'review_score']].drop_duplicates()\n    top_orders = top_orders.sort_values(by='review_score', ascending=False)\n    top_7_orders = top_orders.head(7)\n    return top_7_orders"""
    ),
    (
        "Retrieve top 15 orders with the highest review scores.",
        """def list_top_orders_highest_review_scores(df):\n    top_orders = df[['order_id', 'review_score']].drop_duplicates()\n    top_orders = top_orders.sort_values(by='review_score', ascending=False)\n    top_15_orders = top_orders.head(15)\n    return top_15_orders"""
    ),
    (
        "Find top 20 orders with the highest review scores.",
        """def list_top_orders_highest_review_scores(df):\n    top_orders = df[['order_id', 'review_score']].drop_duplicates()\n    top_orders = top_orders.sort_values(by='review_score', ascending=False)\n    top_20_orders = top_orders.head(20)\n    return top_20_orders"""
    ),
    (
        "Retrieve the top 25 orders with the highest review scores.",
        """def list_top_orders_highest_review_scores(df):\n    top_orders = df[['order_id', 'review_score']].drop_duplicates()\n    top_orders = top_orders.sort_values(by='review_score', ascending=False)\n    top_25_orders = top_orders.head(25)\n    return top_25_orders"""
    ),
    (
        "List top 8 orders with the highest review scores.",
        """def list_top_orders_highest_review_scores(df):\n    top_orders = df[['order_id', 'review_score']].drop_duplicates()\n    top_orders = top_orders.sort_values(by='review_score', ascending=False)\n    top_8_orders = top_orders.head(8)\n    return top_8_orders"""
    ),
    (
        "Show the top 12 orders with the highest review scores.",
        """def list_top_orders_highest_review_scores(df):\n    top_orders = df[['order_id', 'review_score']].drop_duplicates()\n    top_orders = top_orders.sort_values(by='review_score', ascending=False)\n    top_12_orders = top_orders.head(12)\n    return top_12_orders"""
    ),
    (
        "Display top 6 orders with the highest review scores.",
        """def list_top_orders_highest_review_scores(df):\n    top_orders = df[['order_id', 'review_score']].drop_duplicates()\n    top_orders = top_orders.sort_values(by='review_score', ascending=False)\n    top_6_orders = top_orders.head(6)\n    return top_6_orders"""
    ),
    (
        "Retrieve top 11 orders with the highest review scores.",
        """def list_top_orders_highest_review_scores(df):\n    top_orders = df[['order_id', 'review_score']].drop_duplicates()\n    top_orders = top_orders.sort_values(by='review_score', ascending=False)\n    top_11_orders = top_orders.head(11)\n    return top_11_orders"""
    ),
    #9
    (
        "Which product has the minimum price?",
        """def find_product_with_minimum_price(df):\n    new_df = df[['product_id', 'product_category', 'price']].drop_duplicates()\n    min_price_val = new_df['price'].min()\n    product_with_min_price = new_df[new_df['price'] == min_price_val]\n    return product_with_min_price"""
    ),
    (
        "Find the product with the lowest price.",
        """def find_product_with_minimum_price(df):\n    new_df = df[['product_id', 'product_category', 'price']].drop_duplicates()\n    min_price_val = new_df['price'].min()\n    product_with_min_price = new_df[new_df['price'] == min_price_val]\n    return product_with_min_price"""
    ),
    (
        "Which item has the cheapest price?",
        """def find_product_with_minimum_price(df):\n    new_df = df[['product_id', 'product_category', 'price']].drop_duplicates()\n    min_price_val = new_df['price'].min()\n    product_with_min_price = new_df[new_df['price'] == min_price_val]\n    return product_with_min_price"""
    ),
    (
        "Determine the product with the minimum price.",
        """def find_product_with_minimum_price(df):\n    new_df = df[['product_id', 'product_category', 'price']].drop_duplicates()\n    min_price_val = new_df['price'].min()\n    product_with_min_price = new_df[new_df['price'] == min_price_val]\n    return product_with_min_price"""
    ),
    (
        "What is the product with the lowest price?",
        """def find_product_with_minimum_price(df):\n    new_df = df[['product_id', 'product_category', 'price']].drop_duplicates()\n    min_price_val = new_df['price'].min()\n    product_with_min_price = new_df[new_df['price'] == min_price_val]\n    return product_with_min_price"""
    ),
    (
        "List the item that has the minimum price.",
        """def find_product_with_minimum_price(df):\n    new_df = df[['product_id', 'product_category', 'price']].drop_duplicates()\n    min_price_val = new_df['price'].min()\n    product_with_min_price = new_df[new_df['price'] == min_price_val]\n    return product_with_min_price"""
    ),
    (
        "Show the product with the minimum price.",
        """def find_product_with_minimum_price(df):\n    new_df = df[['product_id', 'product_category', 'price']].drop_duplicates()\n    min_price_val = new_df['price'].min()\n    product_with_min_price = new_df[new_df['price'] == min_price_val]\n    return product_with_min_price"""
    ),
    (
        "Display the item with the lowest price.",
        """def find_product_with_minimum_price(df):\n    new_df = df[['product_id', 'product_category', 'price']].drop_duplicates()\n    min_price_val = new_df['price'].min()\n    product_with_min_price = new_df[new_df['price'] == min_price_val]\n    return product_with_min_price"""
    ),
    (
        "Retrieve the product with the minimum price.",
        """def find_product_with_minimum_price(df):\n    new_df = df[['product_id', 'product_category', 'price']].drop_duplicates()\n    min_price_val = new_df['price'].min()\n    product_with_min_price = new_df[new_df['price'] == min_price_val]\n    return product_with_min_price"""
    ),
    (
        "Find out which product has the minimum price.",
        """def find_product_with_minimum_price(df):\n    new_df = df[['product_id', 'product_category', 'price']].drop_duplicates()\n    min_price_val = new_df['price'].min()\n    product_with_min_price = new_df[new_df['price'] == min_price_val]\n    return product_with_min_price"""
    ),
    #10
    (
        "Which product has the minimum price in category Housewares?",
        """def find_product_with_min_price_in_housewares(df):\n    housewares_df = df[df['product_category'] == 'Housewares']\n    housewares_df = housewares_df[['product_id', 'price']].drop_duplicates()\n    min_price_val = housewares_df['price'].min()\n    product_with_min_price = housewares_df[housewares_df['price'] == min_price_val]\n    return product_with_min_price"""
    ),
    (
        "Find the product with the lowest price in Housewares category.",
        """def find_product_with_min_price_in_housewares(df):\n    housewares_df = df[df['product_category'] == 'Housewares']\n    housewares_df = housewares_df[['product_id', 'price']].drop_duplicates()\n    min_price_val = housewares_df['price'].min()\n    product_with_min_price = housewares_df[housewares_df['price'] == min_price_val]\n    return product_with_min_price"""
    ),
    (
        "Which item in Housewares has the minimum price?",
        """def find_product_with_min_price_in_housewares(df):\n    housewares_df = df[df['product_category'] == 'Housewares']\n    housewares_df = housewares_df[['product_id', 'price']].drop_duplicates()\n    min_price_val = housewares_df['price'].min()\n    product_with_min_price = housewares_df[housewares_df['price'] == min_price_val]\n    return product_with_min_price"""
    ),
    (
        "List the product with the lowest price in Housewares.",
        """def find_product_with_min_price_in_housewares(df):\n    housewares_df = df[df['product_category'] == 'Housewares']\n    housewares_df = housewares_df[['product_id', 'price']].drop_duplicates()\n    min_price_val = housewares_df['price'].min()\n    product_with_min_price = housewares_df[housewares_df['price'] == min_price_val]\n    return product_with_min_price"""
    ),
    (
        "Show the item with the minimum price in Housewares category.",
        """def find_product_with_min_price_in_housewares(df):\n    housewares_df = df[df['product_category'] == 'Housewares']\n    housewares_df = housewares_df[['product_id', 'price']].drop_duplicates()\n    min_price_val = housewares_df['price'].min()\n    product_with_min_price = housewares_df[housewares_df['price'] == min_price_val]\n    return product_with_min_price"""
    ),
    (
        "Display the product with the minimum price in Housewares.",
        """def find_product_with_min_price_in_housewares(df):\n    housewares_df = df[df['product_category'] == 'Housewares']\n    housewares_df = housewares_df[['product_id', 'price']].drop_duplicates()\n    min_price_val = housewares_df['price'].min()\n    product_with_min_price = housewares_df[housewares_df['price'] == min_price_val]\n    return product_with_min_price"""
    ),
    (
        "Retrieve the product with the minimum price in Housewares category.",
        """def find_product_with_min_price_in_housewares(df):\n    housewares_df = df[df['product_category'] == 'Housewares']\n    housewares_df = housewares_df[['product_id', 'price']].drop_duplicates()\n    min_price_val = housewares_df['price'].min()\n    product_with_min_price = housewares_df[housewares_df['price'] == min_price_val]\n    return product_with_min_price"""
    ),
    (
        "Get the item with the lowest price in Housewares.",
        """def find_product_with_min_price_in_housewares(df):\n    housewares_df = df[df['product_category'] == 'Housewares']\n    housewares_df = housewares_df[['product_id', 'price']].drop_duplicates()\n    min_price_val = housewares_df['price'].min()\n    product_with_min_price = housewares_df[housewares_df['price'] == min_price_val]\n    return product_with_min_price"""
    ),
    (
        "Find the product that has the minimum price in Housewares category.",
        """def find_product_with_min_price_in_housewares(df):\n    housewares_df = df[df['product_category'] == 'Housewares']\n    housewares_df = housewares_df[['product_id', 'price']].drop_duplicates()\n    min_price_val = housewares_df['price'].min()\n    product_with_min_price = housewares_df[housewares_df['price'] == min_price_val]\n    return product_with_min_price"""
    ),
    (
        "Identify the item with the lowest price in Housewares.",
        """def find_product_with_min_price_in_housewares(df):\n    housewares_df = df[df['product_category'] == 'Housewares']\n    housewares_df = housewares_df[['product_id', 'price']].drop_duplicates()\n    min_price_val = housewares_df['price'].min()\n    product_with_min_price = housewares_df[housewares_df['price'] == min_price_val]\n    return product_with_min_price"""
    ),
    (
        "Which product has the minimum price in category Electronics?",
        """def find_product_with_min_price_in_electronics(df):\n    electronics_df = df[df['product_category'] == 'Electronics']\n    electronics_df = electronics_df[['product_id', 'price']].drop_duplicates()\n    min_price_val = electronics_df['price'].min()\n    product_with_min_price = electronics_df[electronics_df['price'] == min_price_val]\n    return product_with_min_price"""
    ),
    (
        "Which item has the lowest price in category Clothing?",
        """def find_product_with_min_price_in_clothing(df):\n    clothing_df = df[df['product_category'] == 'Clothing']\n    clothing_df = clothing_df[['product_id', 'price']].drop_duplicates()\n    min_price_val = clothing_df['price'].min()\n    product_with_min_price = clothing_df[clothing_df['price'] == min_price_val]\n    return product_with_min_price"""
    ),
    (
        "What is the product with the minimum price in category Books?",
        """def find_product_with_min_price_in_books(df):\n    books_df = df[df['product_category'] == 'Books']\n    books_df = books_df[['product_id', 'price']].drop_duplicates()\n    min_price_val = books_df['price'].min()\n    product_with_min_price = books_df[books_df['price'] == min_price_val]\n    return product_with_min_price"""
    ),
    (
        "Find the product with the lowest price in category Beauty?",
        """def find_product_with_min_price_in_beauty(df):\n    beauty_df = df[df['product_category'] == 'Beauty']\n    beauty_df = beauty_df[['product_id', 'price']].drop_duplicates()\n    min_price_val = beauty_df['price'].min()\n    product_with_min_price = beauty_df[beauty_df['price'] == min_price_val]\n    return product_with_min_price"""
    ),
    (
        "Show the item with the minimum price in category Furniture?",
        """def find_product_with_min_price_in_furniture(df):\n    furniture_df = df[df['product_category'] == 'Furniture']\n    furniture_df = furniture_df[['product_id', 'price']].drop_duplicates()\n    min_price_val = furniture_df['price'].min()\n    product_with_min_price = furniture_df[furniture_df['price'] == min_price_val]\n    return product_with_min_price"""
    ),
    (
        "Display the product with the minimum price in category Sports?",
        """def find_product_with_min_price_in_sports(df):\n    sports_df = df[df['product_category'] == 'Sports']\n    sports_df = sports_df[['product_id', 'price']].drop_duplicates()\n    min_price_val = sports_df['price'].min()\n    product_with_min_price = sports_df[sports_df['price'] == min_price_val]\n    return product_with_min_price"""
    ),
    (
        "Retrieve the product with the minimum price in category Toys?",
        """def find_product_with_min_price_in_toys(df):\n    toys_df = df[df['product_category'] == 'Toys']\n    toys_df = toys_df[['product_id', 'price']].drop_duplicates()\n    min_price_val = toys_df['price'].min()\n    product_with_min_price = toys_df[toys_df['price'] == min_price_val]\n    return product_with_min_price"""
    ),
    (
        "Get the item with the lowest price in category Home?",
        """def find_product_with_min_price_in_home(df):\n    home_df = df[df['product_category'] == 'Home']\n    home_df = home_df[['product_id', 'price']].drop_duplicates()\n    min_price_val = home_df['price'].min()\n    product_with_min_price = home_df[home_df['price'] == min_price_val]\n    return product_with_min_price"""
    ),
    (
        "Find the product that has the minimum price in category Kitchen?",
        """def find_product_with_min_price_in_kitchen(df):\n    kitchen_df = df[df['product_category'] == 'Kitchen']\n    kitchen_df = kitchen_df[['product_id', 'price']].drop_duplicates()\n    min_price_val = kitchen_df['price'].min()\n    product_with_min_price = kitchen_df[kitchen_df['price'] == min_price_val]\n    return product_with_min_price"""
    ),
    #11
    (
        "How many orders were placed on 2024-02-13?",
        """def count_orders_on_date(df):\n    orders_on_date = df[df['timestamp'] == '2024-02-13']\n    unique_orders = orders_on_date['order_id'].drop_duplicates()\n    num_orders = unique_orders.count()\n    return num_orders"""
    ),
    (
        "Count the orders placed on 2024-02-13.",
        """def count_orders_on_date(df):\n    orders_on_date = df[df['timestamp'] == '2024-02-13']\n    unique_orders = orders_on_date['order_id'].drop_duplicates()\n    num_orders = unique_orders.count()\n    return num_orders"""
    ),
    (
        "How many orders occurred on 2024-02-13?",
        """def count_orders_on_date(df):\n    orders_on_date = df[df['timestamp'] == '2024-02-13']\n    unique_orders = orders_on_date['order_id'].drop_duplicates()\n    num_orders = unique_orders.count()\n    return num_orders"""
    ),
    (
        "Find the count of orders placed on 2024-02-13.",
        """def count_orders_on_date(df):\n    orders_on_date = df[df['timestamp'] == '2024-02-13']\n    unique_orders = orders_on_date['order_id'].drop_duplicates()\n    num_orders = unique_orders.count()\n    return num_orders"""
    ),
    (
        "List the number of orders on 2024-02-13.",
        """def count_orders_on_date(df):\n    orders_on_date = df[df['timestamp'] == '2024-02-13']\n    unique_orders = orders_on_date['order_id'].drop_duplicates()\n    num_orders = unique_orders.count()\n    return num_orders"""
    ),
    (
        "How many orders were placed on the date 2024-02-13?",
        """def count_orders_on_date(df):\n    orders_on_date = df[df['timestamp'] == '2024-02-13']\n    unique_orders = orders_on_date['order_id'].drop_duplicates()\n    num_orders = unique_orders.count()\n    return num_orders"""
    ),
    (
        "Display the number of orders on 2024-02-13.",
        """def count_orders_on_date(df):\n    orders_on_date = df[df['timestamp'] == '2024-02-13']\n    unique_orders = orders_on_date['order_id'].drop_duplicates()\n    num_orders = unique_orders.count()\n    return num_orders"""
    ),
    (
        "Retrieve the count of orders placed on 2024-02-13.",
        """def count_orders_on_date(df):\n    orders_on_date = df[df['timestamp'] == '2024-02-13']\n    unique_orders = orders_on_date['order_id'].drop_duplicates()\n    num_orders = unique_orders.count()\n    return num_orders"""
    ),
    (
        "Calculate the number of orders on 2024-02-13.",
        """def count_orders_on_date(df):\n    orders_on_date = df[df['timestamp'] == '2024-02-13']\n    unique_orders = orders_on_date['order_id'].drop_duplicates()\n    num_orders = unique_orders.count()\n    return num_orders"""
    ),
    (
        "What is the count of orders on 2024-02-13?",
        """def count_orders_on_date(df):\n    orders_on_date = df[df['timestamp'] == '2024-02-13']\n    unique_orders = orders_on_date['order_id'].drop_duplicates()\n    num_orders = unique_orders.count()\n    return num_orders"""
    ),
    (
        "How many orders were placed on 2024-02-14?",
        """def count_orders_on_date(df):\n    orders_on_date = df[df['timestamp'] == '2024-02-14']\n    unique_orders = orders_on_date['order_id'].drop_duplicates()\n    num_orders = unique_orders.count()\n    return num_orders"""
    ),
    (
        "Count the orders placed on 2024-02-15.",
        """def count_orders_on_date(df):\n    orders_on_date = df[df['timestamp'] == '2024-02-15']\n    unique_orders = orders_on_date['order_id'].drop_duplicates()\n    num_orders = unique_orders.count()\n    return num_orders"""
    ),
    (
        "How many orders occurred on 2024-02-16?",
        """def count_orders_on_date(df):\n    orders_on_date = df[df['timestamp'] == '2024-02-16']\n    unique_orders = orders_on_date['order_id'].drop_duplicates()\n    num_orders = unique_orders.count()\n    return num_orders"""
    ),
    (
        "Find the count of orders placed on 2024-02-17.",
        """def count_orders_on_date(df):\n    orders_on_date = df[df['timestamp'] == '2024-02-17']\n    unique_orders = orders_on_date['order_id'].drop_duplicates()\n    num_orders = unique_orders.count()\n    return num_orders"""
    ),
    (
        "List the number of orders on 2024-02-18.",
        """def count_orders_on_date(df):\n    orders_on_date = df[df['timestamp'] == '2024-02-18']\n    unique_orders = orders_on_date['order_id'].drop_duplicates()\n    num_orders = unique_orders.count()\n    return num_orders"""
    ),
    (
        "How many orders were placed on the date 2024-02-19?",
        """def count_orders_on_date(df):\n    orders_on_date = df[df['timestamp'] == '2024-02-19']\n    unique_orders = orders_on_date['order_id'].drop_duplicates()\n    num_orders = unique_orders.count()\n    return num_orders"""
    ),
    (
        "Display the number of orders on 2024-02-20.",
        """def count_orders_on_date(df):\n    orders_on_date = df[df['timestamp'] == '2024-02-20']\n    unique_orders = orders_on_date['order_id'].drop_duplicates()\n    num_orders = unique_orders.count()\n    return num_orders"""
    ),
    (
        "Retrieve the count of orders placed on 2024-02-21.",
        """def count_orders_on_date(df):\n    orders_on_date = df[df['timestamp'] == '2024-02-21']\n    unique_orders = orders_on_date['order_id'].drop_duplicates()\n    num_orders = unique_orders.count()\n    return num_orders"""
    ),
    (
        "Calculate the number of orders on 2024-02-22.",
        """def count_orders_on_date(df):\n    orders_on_date = df[df['timestamp'] == '2024-02-22']\n    unique_orders = orders_on_date['order_id'].drop_duplicates()\n    num_orders = unique_orders.count()\n    return num_orders"""
    ),
    #12
    (
        "What is the maximum quantity of products sold in a single order?",
        """def find_max_quantity_per_order(df):\n    max_quantity = df.groupby('order_id')['quantity'].sum().max()\n    return max_quantity"""
    ),
    (
        "Find the highest quantity of products sold in a single order.",
        """def find_max_quantity_per_order(df):\n    max_quantity = df.groupby('order_id')['quantity'].sum().max()\n    return max_quantity"""
    ),
    (
        "Determine the maximum quantity of items sold in one order.",
        """def find_max_quantity_per_order(df):\n    max_quantity = df.groupby('order_id')['quantity'].sum().max()\n    return max_quantity"""
    ),
    (
        "Calculate the max quantity of products sold in any single order.",
        """def find_max_quantity_per_order(df):\n    max_quantity = df.groupby('order_id')['quantity'].sum().max()\n    return max_quantity"""
    ),
    (
        "What is the highest number of products sold in a single order?",
        """def find_max_quantity_per_order(df):\n    max_quantity = df.groupby('order_id')['quantity'].sum().max()\n    return max_quantity"""
    ),
    (
        "List the maximum quantity of products sold in one order.",
        """def find_max_quantity_per_order(df):\n    max_quantity = df.groupby('order_id')['quantity'].sum().max()\n    return max_quantity"""
    ),
    (
        "Show the highest quantity of items sold in any single order.",
        """def find_max_quantity_per_order(df):\n    max_quantity = df.groupby('order_id')['quantity'].sum().max()\n    return max_quantity"""
    ),
    (
        "Display the maximum quantity of products sold in one order.",
        """def find_max_quantity_per_order(df):\n    max_quantity = df.groupby('order_id')['quantity'].sum().max()\n    return max_quantity"""
    ),
    (
        "Retrieve the max quantity of products sold in a single order.",
        """def find_max_quantity_per_order(df):\n    max_quantity = df.groupby('order_id')['quantity'].sum().max()\n    return max_quantity"""
    ),
    (
        "Get the highest number of products sold in one order.",
        """def find_max_quantity_per_order(df):\n    max_quantity = df.groupby('order_id')['quantity'].sum().max()\n    return max_quantity"""
    ),
    #13
    (
        "List orders with a total quantity greater than 2.",
        """def filter_orders_total_quantity_greater_than_2(df):\n    tot_qty_by_order = df.groupby('order_id')['quantity'].sum()\n    orders_greater_than_2 = tot_qty_by_order[tot_qty_by_order > 2]\n    return orders_greater_than_2"""
    ),
    (
        "Show orders where total quantity exceeds 3.",
        """def filter_orders_total_quantity_greater_than_3(df):\n    tot_qty_by_order = df.groupby('order_id')['quantity'].sum()\n    orders_greater_than_3 = tot_qty_by_order[tot_qty_by_order > 3]\n    return orders_greater_than_3"""
    ),
    (
        "Find orders with total quantity more than 4.",
        """def filter_orders_total_quantity_greater_than_4(df):\n    tot_qty_by_order = df.groupby('order_id')['quantity'].sum()\n    orders_greater_than_4 = tot_qty_by_order[tot_qty_by_order > 4]\n    return orders_greater_than_4"""
    ),
    (
        "Display orders having total quantity greater than 12.",
        """def filter_orders_total_quantity_greater_than_12(df):\n    tot_qty_by_order = df.groupby('order_id')['quantity'].sum()\n    orders_greater_than_12 = tot_qty_by_order[tot_qty_by_order > 12]\n    return orders_greater_than_12"""
    ),
    (
        "Retrieve orders where total quantity is above 2.",
        """def filter_orders_total_quantity_greater_than_2(df):\n    tot_qty_by_order = df.groupby('order_id')['quantity'].sum()\n    orders_greater_than_2 = tot_qty_by_order[tot_qty_by_order > 2]\n    return orders_greater_than_2"""
    ),
    (
        "List orders with total quantity exceeding 2.",
        """def filter_orders_total_quantity_greater_than_2(df):\n    tot_qty_by_order = df.groupby('order_id')['quantity'].sum()\n    orders_greater_than_2 = tot_qty_by_order[tot_qty_by_order > 2]\n    return orders_greater_than_2"""
    ),
    (
        "Show orders with a total quantity greater than 2.",
        """def filter_orders_total_quantity_greater_than_2(df):\n    tot_qty_by_order = df.groupby('order_id')['quantity'].sum()\n    orders_greater_than_2 = tot_qty_by_order[tot_qty_by_order > 2]\n    return orders_greater_than_2"""
    ),
    (
        "Find orders where the total quantity is more than 2.",
        """def filter_orders_total_quantity_greater_than_2(df):\n    tot_qty_by_order = df.groupby('order_id')['quantity'].sum()\n    orders_greater_than_2 = tot_qty_by_order[tot_qty_by_order > 2]\n    return orders_greater_than_2"""
    ),
    (
        "Display orders with a total quantity of more than 2.",
        """def filter_orders_total_quantity_greater_than_2(df):\n    tot_qty_by_order = df.groupby('order_id')['quantity'].sum()\n    orders_greater_than_2 = tot_qty_by_order[tot_qty_by_order > 2]\n    return orders_greater_than_2"""
    ),
    (
        "Retrieve orders with total quantity greater than 2.",
        """def filter_orders_total_quantity_greater_than_2(df):\n    tot_qty_by_order = df.groupby('order_id')['quantity'].sum()\n    orders_greater_than_2 = tot_qty_by_order[tot_qty_by_order > 2]\n    return orders_greater_than_2"""
    ),
    #14
    (
        "How many orders were made in February 2024?",
        """def count_orders_in_february_2024(df):\n    feb_2024_orders = df[df['timestamp'].str.startswith('2024-02')]\n    num_orders = feb_2024_orders['order_id'].nunique()\n    return num_orders"""
    ),
    (
        "Count the orders placed in February 2024.",
        """def count_orders_in_february_2024(df):\n    feb_2024_orders = df[df['timestamp'].str.startswith('2024-02')]\n    num_orders = feb_2024_orders['order_id'].nunique()\n    return num_orders"""
    ),
    (
        "How many orders occurred in February 2024?",
        """def count_orders_in_february_2024(df):\n    feb_2024_orders = df[df['timestamp'].str.startswith('2024-02')]\n    num_orders = feb_2024_orders['order_id'].nunique()\n    return num_orders"""
    ),
    (
        "Determine the number of orders in February 2024.",
        """def count_orders_in_february_2024(df):\n    feb_2024_orders = df[df['timestamp'].str.startswith('2024-02')]\n    num_orders = feb_2024_orders['order_id'].nunique()\n    return num_orders"""
    ),
    (
        "What is the count of orders in February 2024?",
        """def count_orders_in_february_2024(df):\n    feb_2024_orders = df[df['timestamp'].str.startswith('2024-02')]\n    num_orders = feb_2024_orders['order_id'].nunique()\n    return num_orders"""
    ),
    (
        "List the number of orders made in February 2024.",
        """def count_orders_in_february_2024(df):\n    feb_2024_orders = df[df['timestamp'].str.startswith('2024-02')]\n    num_orders = feb_2024_orders['order_id'].nunique()\n    return num_orders"""
    ),
    (
        "Show the count of orders placed in February 2024.",
        """def count_orders_in_february_2024(df):\n    feb_2024_orders = df[df['timestamp'].str.startswith('2024-02')]\n    num_orders = feb_2024_orders['order_id'].nunique()\n    return num_orders"""
    ),
    (
        "Display the number of orders in February 2024.",
        """def count_orders_in_february_2024(df):\n    feb_2024_orders = df[df['timestamp'].str.startswith('2024-02')]\n    num_orders = feb_2024_orders['order_id'].nunique()\n    return num_orders"""
    ),
    (
        "Retrieve the number of orders occurring in February 2024.",
        """def count_orders_in_february_2024(df):\n    feb_2024_orders = df[df['timestamp'].str.startswith('2024-02')]\n    num_orders = feb_2024_orders['order_id'].nunique()\n    return num_orders"""
    ),
    (
        "Get the count of orders made in February 2024.",
        """def count_orders_in_february_2024(df):\n    feb_2024_orders = df[df['timestamp'].str.startswith('2024-02')]\n    num_orders = feb_2024_orders['order_id'].nunique()\n    return num_orders"""
    ),
    (
        "How many orders were made in Feb 2024?",
        """def count_orders_in_february_2024(df):\n    feb_2024_orders = df[df['timestamp'].str.startswith('2024-02')]\n    num_orders = feb_2024_orders['order_id'].nunique()\n    return num_orders"""
    ),
    (
        "How many orders were made in June 2023?",
        """def count_orders_in_june_2023(df):\n    jun_2023_orders = df[df['timestamp'].str.startswith('2023-06')]\n    num_orders = jun_2023_orders['order_id'].nunique()\n    return num_orders"""
    ),
    (
        "How many orders were made in November 2025?",
        """def count_orders_in_november_2025(df):\n    nov_2025_orders = df[df['timestamp'].str.startswith('2025-11')]\n    num_orders = nov_2025_orders['order_id'].nunique()\n    return num_orders"""
    ),
    (
        "How many orders were made in April 2022?",
        """def count_orders_in_april_2022(df):\n    apr_2022_orders = df[df['timestamp'].str.startswith('2022-04')]\n    num_orders = apr_2022_orders['order_id'].nunique()\n    return num_orders"""
    ),
    (
        "How many orders were made in September 2026?",
        """def count_orders_in_september_2026(df):\n    sep_2026_orders = df[df['timestamp'].str.startswith('2026-09')]\n    num_orders = sep_2026_orders['order_id'].nunique()\n    return num_orders"""
    ),
    (
        "How many orders were made in December 2027?",
        """def count_orders_in_december_2027(df):\n    dec_2027_orders = df[df['timestamp'].str.startswith('2027-12')]\n    num_orders = dec_2027_orders['order_id'].nunique()\n    return num_orders"""
    ),
    (
        "How many orders were made in August 2028?",
        """def count_orders_in_august_2028(df):\n    aug_2028_orders = df[df['timestamp'].str.startswith('2028-08')]\n    num_orders = aug_2028_orders['order_id'].nunique()\n    return num_orders"""
    ),
    (
        "How many orders were made in March 2029?",
        """def count_orders_in_march_2029(df):\n    mar_2029_orders = df[df['timestamp'].str.startswith('2029-03')]\n    num_orders = mar_2029_orders['order_id'].nunique()\n    return num_orders"""
    ),
    (
        "How many orders were made in May 2030?",
        """def count_orders_in_may_2030(df):\n    may_2030_orders = df[df['timestamp'].str.startswith('2030-05')]\n    num_orders = may_2030_orders['order_id'].nunique()\n    return num_orders"""
    ),
    (
        "How many orders were made in July 2031?",
        """def count_orders_in_july_2031(df):\n    jul_2031_orders = df[df['timestamp'].str.startswith('2031-07')]\n    num_orders = jul_2031_orders['order_id'].nunique()\n    return num_orders"""
    ),
    #15
    (
        "What is the average review score for orders with more than 1 product?",
        """def avg_review_score_for_orders_with_more_than_1_product(df):\n    orders_with_more_than_1_product = df.groupby('order_id').filter(lambda x: len(x) > 1)\n    avg_review_score = orders_with_more_than_1_product['review_score'].mean()\n    return avg_review_score"""
    ),
    (
        "Calculate the average review score for orders having more than 1 product.",
        """def avg_review_score_for_orders_with_more_than_1_product(df):\n    orders_with_more_than_1_product = df.groupby('order_id').filter(lambda x: len(x) > 1)\n    avg_review_score = orders_with_more_than_1_product['review_score'].mean()\n    return avg_review_score"""
    ),
    (
        "Find the mean review score for orders with more than 1 product.",
        """def avg_review_score_for_orders_with_more_than_1_product(df):\n    orders_with_more_than_1_product = df.groupby('order_id').filter(lambda x: len(x) > 1)\n    avg_review_score = orders_with_more_than_1_product['review_score'].mean()\n    return avg_review_score"""
    ),
    (
        "Show the average review score for orders with more than 1 product.",
        """def avg_review_score_for_orders_with_more_than_1_product(df):\n    orders_with_more_than_1_product = df.groupby('order_id').filter(lambda x: len(x) > 1)\n    avg_review_score = orders_with_more_than_1_product['review_score'].mean()\n    return avg_review_score"""
    ),
    (
        "Determine the mean review score for orders having more than 1 product.",
        """def avg_review_score_for_orders_with_more_than_1_product(df):\n    orders_with_more_than_1_product = df.groupby('order_id').filter(lambda x: len(x) > 1)\n    avg_review_score = orders_with_more_than_1_product['review_score'].mean()\n    return avg_review_score"""
    ),
    (
        "Get the average review score for orders with more than 1 product.",
        """def avg_review_score_for_orders_with_more_than_1_product(df):\n    orders_with_more_than_1_product = df.groupby('order_id').filter(lambda x: len(x) > 1)\n    avg_review_score = orders_with_more_than_1_product['review_score'].mean()\n    return avg_review_score"""
    ),
    (
        "Retrieve the mean review score for orders with more than 1 product.",
        """def avg_review_score_for_orders_with_more_than_1_product(df):\n    orders_with_more_than_1_product = df.groupby('order_id').filter(lambda x: len(x) > 1)\n    avg_review_score = orders_with_more_than_1_product['review_score'].mean()\n    return avg_review_score"""
    ),
    (
        "Display the average review score for orders having more than 1 product.",
        """def avg_review_score_for_orders_with_more_than_1_product(df):\n    orders_with_more_than_1_product = df.groupby('order_id').filter(lambda x: len(x) > 1)\n    avg_review_score = orders_with_more_than_1_product['review_score'].mean()\n    return avg_review_score"""
    ),
    (
        "List the mean review score for orders with more than 1 product.",
        """def avg_review_score_for_orders_with_more_than_1_product(df):\n    orders_with_more_than_1_product = df.groupby('order_id').filter(lambda x: len(x) > 1)\n    avg_review_score = orders_with_more_than_1_product['review_score'].mean()\n    return avg_review_score"""
    ),
    (
        "Calculate the average review score for orders with multiple products.",
        """def avg_review_score_for_orders_with_more_than_1_product(df):\n    orders_with_more_than_1_product = df.groupby('order_id').filter(lambda x: len(x) > 1)\n    avg_review_score = orders_with_more_than_1_product['review_score'].mean()\n    return avg_review_score"""
    ),
    (
        "What is the average review score for orders with more than 1 product?",
        """def average_review_score_for_multiple_products(df):\n    orders_with_multiple_products = df.groupby('order_id').filter(lambda x: len(x) > 1)\n    average_review_score = orders_with_multiple_products['review_score'].mean()\n    return average_review_score"""
    ),
    (
        "Find the average review score for orders with 2 or more products.",
        """def average_review_score_for_multiple_products(df):\n    orders_with_multiple_products = df.groupby('order_id').filter(lambda x: len(x) > 1)\n    average_review_score = orders_with_multiple_products['review_score'].mean()\n    return average_review_score"""
    ),
    (
        "Calculate the average review score for orders having more than 1 product.",
        """def average_review_score_for_multiple_products(df):\n    orders_with_multiple_products = df.groupby('order_id').filter(lambda x: len(x) > 1)\n    average_review_score = orders_with_multiple_products['review_score'].mean()\n    return average_review_score"""
    ),
    (
        "Show the average review score for orders containing more than 1 product.",
        """def average_review_score_for_multiple_products(df):\n    orders_with_multiple_products = df.groupby('order_id').filter(lambda x: len(x) > 1)\n    average_review_score = orders_with_multiple_products['review_score'].mean()\n    return average_review_score"""
    ),
    (
        "Display the average review score for orders with multiple products.",
        """def average_review_score_for_multiple_products(df):\n    orders_with_multiple_products = df.groupby('order_id').filter(lambda x: len(x) > 1)\n    average_review_score = orders_with_multiple_products['review_score'].mean()\n    return average_review_score"""
    ),
    (
        "Retrieve the average review score for orders having more than one product.",
        """def average_review_score_for_multiple_products(df):\n    orders_with_multiple_products = df.groupby('order_id').filter(lambda x: len(x) > 1)\n    average_review_score = orders_with_multiple_products['review_score'].mean()\n    return average_review_score"""
    ),
    (
        "Get the average review score for orders with 2 or more products.",
        """def average_review_score_for_multiple_products(df):\n    orders_with_multiple_products = df.groupby('order_id').filter(lambda x: len(x) > 1)\n    average_review_score = orders_with_multiple_products['review_score'].mean()\n    return average_review_score"""
    ),
    (
        "Determine the average review score for orders where the number of products is more than 1.",
        """def average_review_score_for_multiple_products(df):\n    orders_with_multiple_products = df.groupby('order_id').filter(lambda x: len(x) > 1)\n    average_review_score = orders_with_multiple_products['review_score'].mean()\n    return average_review_score"""
    ),
    (
        "List the average review score for orders having multiple products.",
        """def average_review_score_for_multiple_products(df):\n    orders_with_multiple_products = df.groupby('order_id').filter(lambda x: len(x) > 1)\n    average_review_score = orders_with_multiple_products['review_score'].mean()\n    return average_review_score"""
    ),
    (
        "Find the mean review score for orders with more than 1 product.",
        """def average_review_score_for_multiple_products(df):\n    orders_with_multiple_products = df.groupby('order_id').filter(lambda x: len(x) > 1)\n    average_review_score = orders_with_multiple_products['review_score'].mean()\n    return average_review_score"""
    )
]

pd.DataFrame(question_solution_pairs, columns=["question", "solution"])
# Out:
#                                                                                        question  \
# 0                                                  How many transactions were placed in City B?
# 1                                                     How many purchases were placed in City C?
# 2                                                        How many orders were placed in City D?
# 3                                                     How many purchases were placed in City A?
# 4                                                  How many transactions were placed in City C?
# ..                                                                                          ...
# 233                  Retrieve the average review score for orders having more than one product.
# 234                            Get the average review score for orders with 2 or more products.
# 235  Determine the average review score for orders where the number of products is more than 1.
# ...
